# %%
from keras.layers import Input, Conv2D, MaxPooling2D, Dropout, BatchNormalization, Dense, Activation, add, Flatten, GlobalAveragePooling2D, concatenate, Reshape, multiply
from keras.models import Model

from keras.preprocessing.image import ImageDataGenerator
import numpy as np
import tensorflow as tf
from keras.utils import np_utils

width = 32
height = 32

(x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar10.load_data()

# %% [markdown]
# https://keras.io/api/layers/

# %%
num_classes = 10
y_train = np_utils.to_categorical(y_train)
y_test = np_utils.to_categorical(y_test)

# %%
validation_images, validation_labels = x_train[:500], y_train[:500]
train_images, train_labels = x_train[500:], y_train[500:]

# %%
train_images.shape
# Out:
# (49500, 32, 32, 3)

# %%
def SEmodule(pre_layer, ch, r):
  
    x = GlobalAveragePooling2D()(pre_layer)

    x = Dense(int(ch/r), activation='relu')(x)
    
    x = Dense(ch, activation='sigmoid')(x)

    x = Reshape((1, 1, ch))(x)

    x = multiply([pre_layer,x])
    
    return x

# %%
def inception(x, filters): 
    pre_layer = x
    
    f1,f2,f3,f4 = filters

    # 1x1
    conv1 = Conv2D(f1, kernel_size=(1,1), padding='same', activation='relu')(pre_layer)
    
    # 1x1 & 3x3
    conv2 = Conv2D(f4  , kernel_size=(1,1), padding='same', activation='relu')(pre_layer)
    conv2 = Conv2D(f2, kernel_size=(3,3), padding='same', activation='relu')(conv2)

    # 1x1 & 5x5
    conv3 = Conv2D(f4, kernel_size=(1,1), padding='same', activation='relu')(pre_layer)
    conv3 = Conv2D(f3, kernel_size=(5,5), padding='same', activation='relu')(conv3)
    
    # pooling & 1x1
    max_pool = MaxPooling2D(pool_size=(3,3), strides=1, padding='same')(pre_layer)
    max_pool = Conv2D(f4, kernel_size=(1,1), padding='same')(max_pool)

    # output = [None(batch_size), w,h,c], c 기준 concatenate (axis = -1 )
    concat = concatenate([conv1, conv2, conv3, max_pool], axis=-1)
    
    x = SEmodule(concat, f1+f2+f3+f4, 16)

    return x #concat

# %%
input_shape = x_train[0].shape    
inputs = Input(shape=input_shape)

# conv랑 batch 사이에 max pooling 들어가야 하나, cifar 데이터에선 크기 너무 줄어들어서 뺐음
x = Conv2D(64, kernel_size=(7,7), strides=2, padding='same', activation='relu')(inputs)
x = BatchNormalization()(x)
x = Conv2D(192, kernel_size=(3,3), padding='same', activation='relu')(x)
x = BatchNormalization()(x) 


# inception 3a
x = inception(x,[64,128,32,32])
# inception 3b
x = inception(x,[128,192,96,64])
x = MaxPooling2D(pool_size=(3,3), strides=2, padding='same')(x)

# inception 4a
x = inception(x,[192,208,48,64])
aux1 = AveragePooling2D(pool_size=(5,5),strides = 3, padding='valid')(x)
aux1 = Conv2D(128, kernel_size=(1,1), padding='same', activation='relu')(aux1)
aux1 = Flatten()(aux1)
aux1 = Dense(512, activation='relu')(aux1)
aux1 = Dense(10, activation='softmax')(aux1)

# inception 4b
x = inception(x,[160,224,64,64])


# inception 4c
x = inception(x,[128,256,64,64])
# inception 4d
x = inception(x,[112,288,64,64])
aux2 = AveragePooling2D(pool_size=(5,5),strides = 3, padding='valid')(x)
aux2 = Conv2D(128, kernel_size=(1,1), padding='same', activation='relu')(aux2)
aux2 = Flatten()(aux2)
aux2 = Dense(832, activation='relu')(aux2)
aux2 = Dense(10, activation='softmax')(aux2)


# inception 4e
x = inception(x,[256,320,128,128])


# inception 5a
x = inception(x,[256,320,128,128])
# inception 5b
x = inception(x,[384,384,128,128])
x = GlobalAveragePooling2D()(x)
x = Dropout(0.4)(x)
x = Flatten()(x)
outputs = Dense(10, activation='softmax')(x)

model = Model(inputs=inputs, outputs=[aux1, aux2, outputs])

model.compile(optimizer='adam', loss='categorical_crossentropy', loss_weights=[0.3,0.3,1.0], metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_7 (InputLayer)            [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# conv2d_248 (Conv2D)             (None, 16, 16, 64)   9472        input_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 16, 16, 64)   256         conv2d_248[0][0]
# __________________________________________________________________________________________________
# conv2d_249 (Conv2D)             (None, 16, 16, 192)  110784      batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 16, 16, 192)  768         conv2d_249[0][0]
# __________________________________________________________________________________________________
# conv2d_251 (Conv2D)             (None, 16, 16, 32)   6176        batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv2d_253 (Conv2D)             (None, 16, 16, 32)   6176        batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_42 (MaxPooling2D) (None, 16, 16, 192)  0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv2d_250 (Conv2D)             (None, 16, 16, 64)   12352       batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv2d_252 (Conv2D)             (None, 16, 16, 128)  36992       conv2d_251[0][0]
# __________________________________________________________________________________________________
# conv2d_254 (Conv2D)             (None, 16, 16, 32)   25632       conv2d_253[0][0]
# __________________________________________________________________________________________________
# conv2d_255 (Conv2D)             (None, 16, 16, 32)   6176        max_pooling2d_42[0][0]
# __________________________________________________________________________________________________
# concatenate_38 (Concatenate)    (None, 16, 16, 256)  0           conv2d_250[0][0]
#                                                                  conv2d_252[0][0]
#                                                                  conv2d_254[0][0]
#                                                                  conv2d_255[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_3 (Glo (None, 256)          0           concatenate_38[0][0]
# __________________________________________________________________________________________________
# dense_21 (Dense)                (None, 16)           4112        global_average_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# dense_22 (Dense)                (None, 256)          4352        dense_21[0][0]
# __________________________________________________________________________________________________
# reshape_1 (Reshape)             (None, 1, 1, 256)    0           dense_22[0][0]
# __________________________________________________________________________________________________
# multiply (Multiply)             (None, 16, 16, 256)  0           concatenate_38[0][0]
#                                                                  reshape_1[0][0]
# __________________________________________________________________________________________________
# conv2d_257 (Conv2D)             (None, 16, 16, 64)   16448       multiply[0][0]
# __________________________________________________________________________________________________
# conv2d_259 (Conv2D)             (None, 16, 16, 64)   16448       multiply[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_43 (MaxPooling2D) (None, 16, 16, 256)  0           multiply[0][0]
# __________________________________________________________________________________________________
# conv2d_256 (Conv2D)             (None, 16, 16, 128)  32896       multiply[0][0]
# __________________________________________________________________________________________________
# conv2d_258 (Conv2D)             (None, 16, 16, 192)  110784      conv2d_257[0][0]
# __________________________________________________________________________________________________
# conv2d_260 (Conv2D)             (None, 16, 16, 96)   153696      conv2d_259[0][0]
# __________________________________________________________________________________________________
# conv2d_261 (Conv2D)             (None, 16, 16, 64)   16448       max_pooling2d_43[0][0]
# __________________________________________________________________________________________________
# concatenate_39 (Concatenate)    (None, 16, 16, 480)  0           conv2d_256[0][0]
#                                                                  conv2d_258[0][0]
#                                                                  conv2d_260[0][0]
#                                                                  conv2d_261[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_4 (Glo (None, 480)          0           concatenate_39[0][0]
# __________________________________________________________________________________________________
# dense_23 (Dense)                (None, 30)           14430       global_average_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# dense_24 (Dense)                (None, 480)          14880       dense_23[0][0]
# __________________________________________________________________________________________________
# reshape_2 (Reshape)             (None, 1, 1, 480)    0           dense_24[0][0]
# __________________________________________________________________________________________________
# multiply_1 (Multiply)           (None, 16, 16, 480)  0           concatenate_39[0][0]
#                                                                  reshape_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_44 (MaxPooling2D) (None, 8, 8, 480)    0           multiply_1[0][0]
# __________________________________________________________________________________________________
# conv2d_263 (Conv2D)             (None, 8, 8, 64)     30784       max_pooling2d_44[0][0]
# __________________________________________________________________________________________________
# conv2d_265 (Conv2D)             (None, 8, 8, 64)     30784       max_pooling2d_44[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_45 (MaxPooling2D) (None, 8, 8, 480)    0           max_pooling2d_44[0][0]
# __________________________________________________________________________________________________
# conv2d_262 (Conv2D)             (None, 8, 8, 192)    92352       max_pooling2d_44[0][0]
# __________________________________________________________________________________________________
# conv2d_264 (Conv2D)             (None, 8, 8, 208)    120016      conv2d_263[0][0]
# __________________________________________________________________________________________________
# conv2d_266 (Conv2D)             (None, 8, 8, 48)     76848       conv2d_265[0][0]
# __________________________________________________________________________________________________
# conv2d_267 (Conv2D)             (None, 8, 8, 64)     30784       max_pooling2d_45[0][0]
# __________________________________________________________________________________________________
# concatenate_40 (Concatenate)    (None, 8, 8, 512)    0           conv2d_262[0][0]
#                                                                  conv2d_264[0][0]
#                                                                  conv2d_266[0][0]
#                                                                  conv2d_267[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_5 (Glo (None, 512)          0           concatenate_40[0][0]
# __________________________________________________________________________________________________
# dense_25 (Dense)                (None, 32)           16416       global_average_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# dense_26 (Dense)                (None, 512)          16896       dense_25[0][0]
# __________________________________________________________________________________________________
# reshape_3 (Reshape)             (None, 1, 1, 512)    0           dense_26[0][0]
# __________________________________________________________________________________________________
# multiply_2 (Multiply)           (None, 8, 8, 512)    0           concatenate_40[0][0]
#                                                                  reshape_3[0][0]
# __________________________________________________________________________________________________
# conv2d_270 (Conv2D)             (None, 8, 8, 64)     32832       multiply_2[0][0]
# __________________________________________________________________________________________________
# conv2d_272 (Conv2D)             (None, 8, 8, 64)     32832       multiply_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_46 (MaxPooling2D) (None, 8, 8, 512)    0           multiply_2[0][0]
# __________________________________________________________________________________________________
# conv2d_269 (Conv2D)             (None, 8, 8, 160)    82080       multiply_2[0][0]
# __________________________________________________________________________________________________
# conv2d_271 (Conv2D)             (None, 8, 8, 224)    129248      conv2d_270[0][0]
# __________________________________________________________________________________________________
# conv2d_273 (Conv2D)             (None, 8, 8, 64)     102464      conv2d_272[0][0]
# __________________________________________________________________________________________________
# conv2d_274 (Conv2D)             (None, 8, 8, 64)     32832       max_pooling2d_46[0][0]
# __________________________________________________________________________________________________
# concatenate_41 (Concatenate)    (None, 8, 8, 512)    0           conv2d_269[0][0]
#                                                                  conv2d_271[0][0]
#                                                                  conv2d_273[0][0]
#                                                                  conv2d_274[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_6 (Glo (None, 512)          0           concatenate_41[0][0]
# __________________________________________________________________________________________________
# dense_29 (Dense)                (None, 32)           16416       global_average_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# dense_30 (Dense)                (None, 512)          16896       dense_29[0][0]
# __________________________________________________________________________________________________
# reshape_4 (Reshape)             (None, 1, 1, 512)    0           dense_30[0][0]
# __________________________________________________________________________________________________
# multiply_3 (Multiply)           (None, 8, 8, 512)    0           concatenate_41[0][0]
#                                                                  reshape_4[0][0]
# __________________________________________________________________________________________________
# conv2d_276 (Conv2D)             (None, 8, 8, 64)     32832       multiply_3[0][0]
# __________________________________________________________________________________________________
# conv2d_278 (Conv2D)             (None, 8, 8, 64)     32832       multiply_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_47 (MaxPooling2D) (None, 8, 8, 512)    0           multiply_3[0][0]
# __________________________________________________________________________________________________
# conv2d_275 (Conv2D)             (None, 8, 8, 128)    65664       multiply_3[0][0]
# __________________________________________________________________________________________________
# conv2d_277 (Conv2D)             (None, 8, 8, 256)    147712      conv2d_276[0][0]
# __________________________________________________________________________________________________
# conv2d_279 (Conv2D)             (None, 8, 8, 64)     102464      conv2d_278[0][0]
# __________________________________________________________________________________________________
# conv2d_280 (Conv2D)             (None, 8, 8, 64)     32832       max_pooling2d_47[0][0]
# __________________________________________________________________________________________________
# concatenate_42 (Concatenate)    (None, 8, 8, 512)    0           conv2d_275[0][0]
#                                                                  conv2d_277[0][0]
#                                                                  conv2d_279[0][0]
#                                                                  conv2d_280[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_7 (Glo (None, 512)          0           concatenate_42[0][0]
# __________________________________________________________________________________________________
# dense_31 (Dense)                (None, 32)           16416       global_average_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# dense_32 (Dense)                (None, 512)          16896       dense_31[0][0]
# __________________________________________________________________________________________________
# reshape_5 (Reshape)             (None, 1, 1, 512)    0           dense_32[0][0]
# __________________________________________________________________________________________________
# multiply_4 (Multiply)           (None, 8, 8, 512)    0           concatenate_42[0][0]
#                                                                  reshape_5[0][0]
# __________________________________________________________________________________________________
# conv2d_282 (Conv2D)             (None, 8, 8, 64)     32832       multiply_4[0][0]
# __________________________________________________________________________________________________
# conv2d_284 (Conv2D)             (None, 8, 8, 64)     32832       multiply_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_48 (MaxPooling2D) (None, 8, 8, 512)    0           multiply_4[0][0]
# __________________________________________________________________________________________________
# conv2d_281 (Conv2D)             (None, 8, 8, 112)    57456       multiply_4[0][0]
# __________________________________________________________________________________________________
# conv2d_283 (Conv2D)             (None, 8, 8, 288)    166176      conv2d_282[0][0]
# __________________________________________________________________________________________________
# conv2d_285 (Conv2D)             (None, 8, 8, 64)     102464      conv2d_284[0][0]
# __________________________________________________________________________________________________
# conv2d_286 (Conv2D)             (None, 8, 8, 64)     32832       max_pooling2d_48[0][0]
# __________________________________________________________________________________________________
# concatenate_43 (Concatenate)    (None, 8, 8, 528)    0           conv2d_281[0][0]
#                                                                  conv2d_283[0][0]
#                                                                  conv2d_285[0][0]
#                                                                  conv2d_286[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_8 (Glo (None, 528)          0           concatenate_43[0][0]
# __________________________________________________________________________________________________
# dense_33 (Dense)                (None, 33)           17457       global_average_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# dense_34 (Dense)                (None, 528)          17952       dense_33[0][0]
# __________________________________________________________________________________________________
# reshape_6 (Reshape)             (None, 1, 1, 528)    0           dense_34[0][0]
# __________________________________________________________________________________________________
# multiply_5 (Multiply)           (None, 8, 8, 528)    0           concatenate_43[0][0]
#                                                                  reshape_6[0][0]
# __________________________________________________________________________________________________
# conv2d_289 (Conv2D)             (None, 8, 8, 128)    67712       multiply_5[0][0]
# __________________________________________________________________________________________________
# conv2d_291 (Conv2D)             (None, 8, 8, 128)    67712       multiply_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_49 (MaxPooling2D) (None, 8, 8, 528)    0           multiply_5[0][0]
# __________________________________________________________________________________________________
# conv2d_288 (Conv2D)             (None, 8, 8, 256)    135424      multiply_5[0][0]
# __________________________________________________________________________________________________
# conv2d_290 (Conv2D)             (None, 8, 8, 320)    368960      conv2d_289[0][0]
# __________________________________________________________________________________________________
# conv2d_292 (Conv2D)             (None, 8, 8, 128)    409728      conv2d_291[0][0]
# __________________________________________________________________________________________________
# conv2d_293 (Conv2D)             (None, 8, 8, 128)    67712       max_pooling2d_49[0][0]
# __________________________________________________________________________________________________
# concatenate_44 (Concatenate)    (None, 8, 8, 832)    0           conv2d_288[0][0]
#                                                                  conv2d_290[0][0]
#                                                                  conv2d_292[0][0]
#                                                                  conv2d_293[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_9 (Glo (None, 832)          0           concatenate_44[0][0]
# __________________________________________________________________________________________________
# dense_37 (Dense)                (None, 52)           43316       global_average_pooling2d_9[0][0]
# __________________________________________________________________________________________________
# dense_38 (Dense)                (None, 832)          44096       dense_37[0][0]
# __________________________________________________________________________________________________
# reshape_7 (Reshape)             (None, 1, 1, 832)    0           dense_38[0][0]
# __________________________________________________________________________________________________
# multiply_6 (Multiply)           (None, 8, 8, 832)    0           concatenate_44[0][0]
#                                                                  reshape_7[0][0]
# __________________________________________________________________________________________________
# conv2d_295 (Conv2D)             (None, 8, 8, 128)    106624      multiply_6[0][0]
# __________________________________________________________________________________________________
# conv2d_297 (Conv2D)             (None, 8, 8, 128)    106624      multiply_6[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_50 (MaxPooling2D) (None, 8, 8, 832)    0           multiply_6[0][0]
# __________________________________________________________________________________________________
# conv2d_294 (Conv2D)             (None, 8, 8, 256)    213248      multiply_6[0][0]
# __________________________________________________________________________________________________
# conv2d_296 (Conv2D)             (None, 8, 8, 320)    368960      conv2d_295[0][0]
# __________________________________________________________________________________________________
# conv2d_298 (Conv2D)             (None, 8, 8, 128)    409728      conv2d_297[0][0]
# __________________________________________________________________________________________________
# conv2d_299 (Conv2D)             (None, 8, 8, 128)    106624      max_pooling2d_50[0][0]
# __________________________________________________________________________________________________
# concatenate_45 (Concatenate)    (None, 8, 8, 832)    0           conv2d_294[0][0]
#                                                                  conv2d_296[0][0]
#                                                                  conv2d_298[0][0]
#                                                                  conv2d_299[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_10 (Gl (None, 832)          0           concatenate_45[0][0]
# __________________________________________________________________________________________________
# dense_39 (Dense)                (None, 52)           43316       global_average_pooling2d_10[0][0]
# __________________________________________________________________________________________________
# dense_40 (Dense)                (None, 832)          44096       dense_39[0][0]
# __________________________________________________________________________________________________
# reshape_8 (Reshape)             (None, 1, 1, 832)    0           dense_40[0][0]
# __________________________________________________________________________________________________
# multiply_7 (Multiply)           (None, 8, 8, 832)    0           concatenate_45[0][0]
#                                                                  reshape_8[0][0]
# __________________________________________________________________________________________________
# conv2d_301 (Conv2D)             (None, 8, 8, 128)    106624      multiply_7[0][0]
# __________________________________________________________________________________________________
# conv2d_303 (Conv2D)             (None, 8, 8, 128)    106624      multiply_7[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_51 (MaxPooling2D) (None, 8, 8, 832)    0           multiply_7[0][0]
# __________________________________________________________________________________________________
# conv2d_300 (Conv2D)             (None, 8, 8, 384)    319872      multiply_7[0][0]
# __________________________________________________________________________________________________
# conv2d_302 (Conv2D)             (None, 8, 8, 384)    442752      conv2d_301[0][0]
# __________________________________________________________________________________________________
# conv2d_304 (Conv2D)             (None, 8, 8, 128)    409728      conv2d_303[0][0]
# __________________________________________________________________________________________________
# conv2d_305 (Conv2D)             (None, 8, 8, 128)    106624      max_pooling2d_51[0][0]
# __________________________________________________________________________________________________
# concatenate_46 (Concatenate)    (None, 8, 8, 1024)   0           conv2d_300[0][0]
#                                                                  conv2d_302[0][0]
#                                                                  conv2d_304[0][0]
#                                                                  conv2d_305[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_11 (Gl (None, 1024)         0           concatenate_46[0][0]
# __________________________________________________________________________________________________
# dense_41 (Dense)                (None, 64)           65600       global_average_pooling2d_11[0][0]
# __________________________________________________________________________________________________
# dense_42 (Dense)                (None, 1024)         66560       dense_41[0][0]
# __________________________________________________________________________________________________
# reshape_9 (Reshape)             (None, 1, 1, 1024)   0           dense_42[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_8 (AveragePoo (None, 2, 2, 512)    0           multiply_2[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_9 (AveragePoo (None, 2, 2, 528)    0           multiply_5[0][0]
# __________________________________________________________________________________________________
# multiply_8 (Multiply)           (None, 8, 8, 1024)   0           concatenate_46[0][0]
#                                                                  reshape_9[0][0]
# __________________________________________________________________________________________________
# conv2d_268 (Conv2D)             (None, 2, 2, 128)    65664       average_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_287 (Conv2D)             (None, 2, 2, 128)    67712       average_pooling2d_9[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_12 (Gl (None, 1024)         0           multiply_8[0][0]
# __________________________________________________________________________________________________
# flatten_9 (Flatten)             (None, 512)          0           conv2d_268[0][0]
# __________________________________________________________________________________________________
# flatten_10 (Flatten)            (None, 512)          0           conv2d_287[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 1024)         0           global_average_pooling2d_12[0][0]
# __________________________________________________________________________________________________
# dense_27 (Dense)                (None, 512)          262656      flatten_9[0][0]
# __________________________________________________________________________________________________
# dense_35 (Dense)                (None, 832)          426816      flatten_10[0][0]
# __________________________________________________________________________________________________
# flatten_11 (Flatten)            (None, 1024)         0           dropout_1[0][0]
# __________________________________________________________________________________________________
# dense_28 (Dense)                (None, 10)           5130        dense_27[0][0]
# __________________________________________________________________________________________________
# dense_36 (Dense)                (None, 10)           8330        dense_35[0][0]
# __________________________________________________________________________________________________
# dense_43 (Dense)                (None, 10)           10250       flatten_11[0][0]
# ==================================================================================================
# Total params: 7,442,229
# Trainable params: 7,441,717
# Non-trainable params: 512
# __________________________________________________________________________________________________

# %%
train_datagen = ImageDataGenerator(rescale = 1./255,
                                   shear_range = 0.2,
                                   zoom_range = 0.2,
                                   horizontal_flip = True)

validation_datagen = ImageDataGenerator(rescale = 1./255,
                                   shear_range = 0.2,
                                   zoom_range = 0.2,
                                   horizontal_flip = True)

# %%
history = model.fit_generator(train_datagen.flow(train_images,train_labels, batch_size = 32), 
                    validation_data = validation_datagen.flow(validation_images, validation_labels, batch_size = 32),
                    epochs = 10)
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py:1844: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/10
# 1547/1547 [==============================] - 75s 46ms/step - loss: 2.9648 - dense_28_loss: 1.7627 - dense_36_loss: 1.8411 - dense_43_loss: 1.8837 - dense_28_accuracy: 0.3372 - dense_36_accuracy: 0.2951 - dense_43_accuracy: 0.2670 - val_loss: 2.1990 - val_dense_28_loss: 1.3472 - val_dense_36_loss: 1.3860 - val_dense_43_loss: 1.3790 - val_dense_28_accuracy: 0.5160 - val_dense_36_accuracy: 0.4880 - val_dense_43_accuracy: 0.4980
# Epoch 2/10
# 1547/1547 [==============================] - 70s 45ms/step - loss: 2.1571 - dense_28_loss: 1.2932 - dense_36_loss: 1.3461 - dense_43_loss: 1.3653 - dense_28_accuracy: 0.5300 - dense_36_accuracy: 0.5094 - dense_43_accuracy: 0.5036 - val_loss: 1.8317 - val_dense_28_loss: 1.1438 - val_dense_36_loss: 1.1380 - val_dense_43_loss: 1.1472 - val_dense_28_accuracy: 0.5900 - val_dense_36_accuracy: 0.5920 - val_dense_43_accuracy: 0.6000
# Epoch 3/10
# 1547/1547 [==============================] - 70s 45ms/step - loss: 1.7226 - dense_28_loss: 1.0348 - dense_36_loss: 1.0716 - dense_43_loss: 1.0907 - dense_28_accuracy: 0.6306 - dense_36_accuracy: 0.6198 - dense_43_accuracy: 0.6178 - val_loss: 1.4465 - val_dense_28_loss: 0.8931 - val_dense_36_loss: 0.9072 - val_dense_43_loss: 0.9064 - val_dense_28_accuracy: 0.6880 - val_dense_36_accuracy: 0.6860 - val_dense_43_accuracy: 0.6900
# Epoch 4/10
# 1547/1547 [==============================] - 70s 45ms/step - loss: 1.4293 - dense_28_loss: 0.8659 - dense_36_loss: 0.8879 - dense_43_loss: 0.9032 - dense_28_accuracy: 0.6935 - dense_36_accuracy: 0.6902 - dense_43_accuracy: 0.6847 - val_loss: 1.3531 - val_dense_28_loss: 0.8234 - val_dense_36_loss: 0.8497 - val_dense_43_loss: 0.8512 - val_dense_28_accuracy: 0.7000 - val_dense_36_accuracy: 0.7100 - val_dense_43_accuracy: 0.6880
# Epoch 5/10
# 1547/1547 [==============================] - 70s 45ms/step - loss: 1.2347 - dense_28_loss: 0.7549 - dense_36_loss: 0.7645 - dense_43_loss: 0.7789 - dense_28_accuracy: 0.7365 - dense_36_accuracy: 0.7368 - dense_43_accuracy: 0.7340 - val_loss: 1.1638 - val_dense_28_loss: 0.7513 - val_dense_36_loss: 0.7232 - val_dense_43_loss: 0.7214 - val_dense_28_accuracy: 0.7400 - val_dense_36_accuracy: 0.7500 - val_dense_43_accuracy: 0.7420
# Epoch 6/10
# 1547/1547 [==============================] - 70s 45ms/step - loss: 1.1066 - dense_28_loss: 0.6833 - dense_36_loss: 0.6846 - dense_43_loss: 0.6962 - dense_28_accuracy: 0.7631 - dense_36_accuracy: 0.7641 - dense_43_accuracy: 0.7628 - val_loss: 1.1538 - val_dense_28_loss: 0.7261 - val_dense_36_loss: 0.7166 - val_dense_43_loss: 0.7210 - val_dense_28_accuracy: 0.7580 - val_dense_36_accuracy: 0.7540 - val_dense_43_accuracy: 0.7580
# Epoch 7/10
# 1547/1547 [==============================] - 71s 46ms/step - loss: 1.0334 - dense_28_loss: 0.6380 - dense_36_loss: 0.6369 - dense_43_loss: 0.6509 - dense_28_accuracy: 0.7775 - dense_36_accuracy: 0.7810 - dense_43_accuracy: 0.7797 - val_loss: 1.0417 - val_dense_28_loss: 0.6315 - val_dense_36_loss: 0.6588 - val_dense_43_loss: 0.6546 - val_dense_28_accuracy: 0.7760 - val_dense_36_accuracy: 0.7840 - val_dense_43_accuracy: 0.7720
# Epoch 8/10
# 1547/1547 [==============================] - 70s 45ms/step - loss: 0.9506 - dense_28_loss: 0.5877 - dense_36_loss: 0.5845 - dense_43_loss: 0.5990 - dense_28_accuracy: 0.7964 - dense_36_accuracy: 0.8018 - dense_43_accuracy: 0.7967 - val_loss: 1.0999 - val_dense_28_loss: 0.7018 - val_dense_36_loss: 0.6790 - val_dense_43_loss: 0.6856 - val_dense_28_accuracy: 0.7600 - val_dense_36_accuracy: 0.7620 - val_dense_43_accuracy: 0.7680
# Epoch 9/10
# 1547/1547 [==============================] - 70s 45ms/step - loss: 0.8926 - dense_28_loss: 0.5559 - dense_36_loss: 0.5496 - dense_43_loss: 0.5609 - dense_28_accuracy: 0.8025 - dense_36_accuracy: 0.8122 - dense_43_accuracy: 0.8094 - val_loss: 0.8938 - val_dense_28_loss: 0.5401 - val_dense_36_loss: 0.5501 - val_dense_43_loss: 0.5667 - val_dense_28_accuracy: 0.8060 - val_dense_36_accuracy: 0.7980 - val_dense_43_accuracy: 0.7960
# Epoch 10/10
# 1547/1547 [==============================] - 70s 45ms/step - loss: 0.8326 - dense_28_loss: 0.5218 - dense_36_loss: 0.5116 - dense_43_loss: 0.5226 - dense_28_accuracy: 0.8177 - dense_36_accuracy: 0.8224 - dense_43_accuracy: 0.8210 - val_loss: 0.8723 - val_dense_28_loss: 0.5367 - val_dense_36_loss: 0.5398 - val_dense_43_loss: 0.5493 - val_dense_28_accuracy: 0.8140 - val_dense_36_accuracy: 0.8220 - val_dense_43_accuracy: 0.8220

# %%
import matplotlib.pyplot as plt

acc = history.history['dense_13_accuracy']
val_acc = history.history['val_dense_13_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(10)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-30-5947dc8da6b1> in <module>()
#       1 import matplotlib.pyplot as plt
#       2
# ----> 3 acc = history.history['dense_13_accuracy']
#       4 val_acc = history.history['val_dense_13_accuracy']
#       5
#
# KeyError: 'dense_13_accuracy'
